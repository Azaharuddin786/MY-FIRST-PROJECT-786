# %% [markdown]
# <a href="https://colab.research.google.com/github/Azaharuddin786/MY-FIRST-PROJECT-786/blob/main/smoothing_image_BY_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv2
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt

# %%
urls = ['/content/photo-1552519507-da3b142c6e3d.jpg']
for url in urls:
  image = cv2.imread(url)
  image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=1000x667 at 0x7F129C84BD90>

# %%
kernel = np.ones((5,5), np.float32)/25

# %%
dst = cv2.filter2D(image, -1, kernel)

# %%
blur = cv2.blur(image, (5,5))

# %%
gblur = cv2.GaussianBlur(image, (5,5), 0)

# %%
median = cv2.medianBlur(image, 5)

# %%
bilateralFilter = cv2.bilateralFilter(image, 9, 75, 75)

# %%
titles = ["image', '2D Convolution', 'blur', 'GaussianBlur', 'median', 'bilateralFilter"]

# %%
images = [image, dst, blur, gblur, median, bilateralFilter]

# %%
for i in range(6):
  plt.subplot(2, 3, i+1), plt.imshow(images[i], 'gray')
  plt.xticks([])
  plt.yticks([])
  plt.show()
