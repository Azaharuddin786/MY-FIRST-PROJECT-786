# %% [markdown]
# <a href="https://colab.research.google.com/github/Azaharuddin786/MY-FIRST-PROJECT-786/blob/main/albumentation_that_means_data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image
import cv2
from  google.colab.patches import cv2_imshow
import albumentations as A
import matplotlib.pyplot as plt

# %%
pip install pillow

# %%
image = Image.open('/content/6dfc0d4283e3c21fe6f3416e2172178d.jpg')

# %%
transform = A.Compose(
    [
        A.Resize(width=1920, height=1080),
        A.RandomCrop(width=1280, height=720),
        A.Rotate(limit=40, p=0.9, border_mode=cv2.BORDER_CONSTANT),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.1),
        A.RGBShift(r_shift_limit=25, g_shift_limit=25, b_shift_limit=25, p=0.9),
        A.OneOf([
            A.Blur(blur_limit=3, p=0.5),
            
        ], p=1.0),
    ]
)

# %%
pillow_image = Image.open('/content/6dfc0d4283e3c21fe6f3416e2172178d.jpg')
image = np.array(pillow_image)

# %%
transformed = transform(image=image)

# %%
transformed_image = transformed["image"]

# %%
another_transformed_image = transform(image=image)["image"]

# %%
transform = A.Compose([
    A.RandomBrightnessContrast(brightness_limit=1, contrast_limit=1, p=1.0),
    A.Resize(width=1920, height=1080),
    A.RandomCrop(width=1280, height=720),
    A.Rotate(limit=40, p=0.9, border_mode=cv2.BORDER_CONSTANT),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.1),

])
transformed_image_1 = transform(image=image)['image']
transformed_image_2 = transform(image=image)['image']
transformed_image_3 = transform(image=image)['image']

# %%
cv2_imshow(transformed_image_1)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F60E5861E50>

# %%
cv2_imshow(transformed_image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F60E612D750>

# %%
cv2_imshow(transformed_image_3)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F60E585BC50>

# %%
cv2_imshow(transformed_image_3)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F60E5908C10>
